# %%
pip install vaex dash plotly plotly-geo geopandas pyshp shapely numpy pandas
# Out:
# Requirement already satisfied: vaex in /Users/vamshisaggurthi/opt/anaconda3/lib/python3.9/site-packages (4.8.0)
# Requirement already satisfied: dash in /Users/vamshisaggurthi/opt/anaconda3/lib/python3.9/site-packages (2.2.0)
# Requirement already satisfied: plotly in /Users/vamshisaggurthi/opt/anaconda3/lib/python3.9/site-packages (5.6.0)
# Requirement already satisfied: plotly-geo in /Users/vamshisaggurthi/opt/anaconda3/lib/python3.9/site-packages (1.0.0)
# Requirement already satisfied: geopandas in /Users/vamshisaggurthi/opt/anaconda3/lib/python3.9/site-packages (0.10.2)
# Requirement already satisfied: pyshp in /Users/vamshisaggurthi/opt/anaconda3/lib/python3.9/site-packages (2.2.0)
# Requirement already satisfied: shapely in /Users/vamshisaggurthi/opt/anaconda3/lib/python3.9/site-packages (1.8.0)
# Requirement already satisfied: numpy in /Users/vamshisaggurthi/opt/anaconda3/lib/python3.9/site-packages (1.20.3)
# Requirement already satisfied: pandas in /Users/vamshisaggurthi/opt/anaconda3/lib/python3.9/site-packages (1.3.4)
# Requirement already satisfied: vaex-core<4.9,>=4.8.0 in /Users/vamshisaggurthi/opt/anaconda3/lib/python3.9/site-packages (from vaex) (4.8.0)
# Requirement already satisfied: vaex-viz<0.6,>=0.5.1 in /Users/vamshisaggurthi/opt/anaconda3/lib/python3.9/site-packages (from vaex) (0.5.1)
# Requirement already satisfied: vaex-server<0.9,>=0.8.1 in /Users/vamshisaggurthi/opt/anaconda3/lib/python3.9/site-packages (from vaex) (0.8.1)
# Requirement already satisfied: vaex-ml<0.18,>=0.17.0 in /Users/vamshisaggurthi/opt/anaconda3/lib/python3.9/site-packages (from vaex) (0.17.0)
# Requirement already satisfied: vaex-hdf5<0.13,>=0.12.0 in /Users/vamshisaggurthi/opt/anaconda3/lib/python3.9/site-packages (from vaex) (0.12.0)
# Requirement already satisfied: vaex-astro<0.10,>=0.9.0 in /Users/vamshisaggurthi/opt/anaconda3/lib/python3.9/site-packages (from vaex) (0.9.0)
# Requirement already satisfied: vaex-jupyter<0.8,>=0.7.0 in /Users/vamshisaggurthi/opt/anaconda3/lib/python3.9/site-packages (from vaex) (0.7.0)
# Requirement already satisfied: dash-table==5.0.0 in /Users/vamshisaggurthi/opt/anaconda3/lib/python3.9/site-packages (from dash) (5.0.0)
# Requirement already satisfied: flask-compress in /Users/vamshisaggurthi/opt/anaconda3/lib/python3.9/site-packages (from dash) (1.11)
# Requirement already satisfied: dash-html-components==2.0.0 in /Users/vamshisaggurthi/opt/anaconda3/lib/python3.9/site-packages (from dash) (2.0.0)
# Requirement already satisfied: dash-core-components==2.0.0 in /Users/vamshisaggurthi/opt/anaconda3/lib/python3.9/site-packages (from dash) (2.0.0)
# Requirement already satisfied: Flask>=1.0.4 in /Users/vamshisaggurthi/opt/anaconda3/lib/python3.9/site-packages (from dash) (1.1.2)
# Requirement already satisfied: six in /Users/vamshisaggurthi/opt/anaconda3/lib/python3.9/site-packages (from plotly) (1.16.0)
# Requirement already satisfied: tenacity>=6.2.0 in /Users/vamshisaggurthi/opt/anaconda3/lib/python3.9/site-packages (from plotly) (8.0.1)
# Requirement already satisfied: pyproj>=2.2.0 in /Users/vamshisaggurthi/opt/anaconda3/lib/python3.9/site-packages (from geopandas) (3.3.0)
# Requirement already satisfied: fiona>=1.8 in /Users/vamshisaggurthi/opt/anaconda3/lib/python3.9/site-packages (from geopandas) (1.8.21)
# Requirement already satisfied: python-dateutil>=2.7.3 in /Users/vamshisaggurthi/opt/anaconda3/lib/python3.9/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /Users/vamshisaggurthi/opt/anaconda3/lib/python3.9/site-packages (from pandas) (2021.3)
# Requirement already satisfied: setuptools in /Users/vamshisaggurthi/opt/anaconda3/lib/python3.9/site-packages (from fiona>=1.8->geopandas) (58.0.4)
# Requirement already satisfied: cligj>=0.5 in /Users/vamshisaggurthi/opt/anaconda3/lib/python3.9/site-packages (from fiona>=1.8->geopandas) (0.7.2)
# Requirement already satisfied: click-plugins>=1.0 in /Users/vamshisaggurthi/opt/anaconda3/lib/python3.9/site-packages (from fiona>=1.8->geopandas) (1.1.1)
# Requirement already satisfied: munch in /Users/vamshisaggurthi/opt/anaconda3/lib/python3.9/site-packages (from fiona>=1.8->geopandas) (2.5.0)
# Requirement already satisfied: certifi in /Users/vamshisaggurthi/opt/anaconda3/lib/python3.9/site-packages (from fiona>=1.8->geopandas) (2021.10.8)
# Requirement already satisfied: attrs>=17 in /Users/vamshisaggurthi/opt/anaconda3/lib/python3.9/site-packages (from fiona>=1.8->geopandas) (21.2.0)
# Requirement already satisfied: click>=4.0 in /Users/vamshisaggurthi/opt/anaconda3/lib/python3.9/site-packages (from fiona>=1.8->geopandas) (8.0.3)
# Requirement already satisfied: itsdangerous>=0.24 in /Users/vamshisaggurthi/opt/anaconda3/lib/python3.9/site-packages (from Flask>=1.0.4->dash) (2.0.1)
# Requirement already satisfied: Jinja2>=2.10.1 in /Users/vamshisaggurthi/opt/anaconda3/lib/python3.9/site-packages (from Flask>=1.0.4->dash) (2.11.3)
# Requirement already satisfied: Werkzeug>=0.15 in /Users/vamshisaggurthi/opt/anaconda3/lib/python3.9/site-packages (from Flask>=1.0.4->dash) (2.0.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /Users/vamshisaggurthi/opt/anaconda3/lib/python3.9/site-packages (from Jinja2>=2.10.1->Flask>=1.0.4->dash) (1.1.1)
# Requirement already satisfied: astropy in /Users/vamshisaggurthi/opt/anaconda3/lib/python3.9/site-packages (from vaex-astro<0.10,>=0.9.0->vaex) (4.3.1)
# Requirement already satisfied: progressbar2 in /Users/vamshisaggurthi/opt/anaconda3/lib/python3.9/site-packages (from vaex-core<4.9,>=4.8.0->vaex) (4.0.0)
# Requirement already satisfied: dask in /Users/vamshisaggurthi/opt/anaconda3/lib/python3.9/site-packages (from vaex-core<4.9,>=4.8.0->vaex) (2021.10.0)
# Requirement already satisfied: tabulate>=0.8.3 in /Users/vamshisaggurthi/opt/anaconda3/lib/python3.9/site-packages (from vaex-core<4.9,>=4.8.0->vaex) (0.8.9)
# Requirement already satisfied: pydantic>=1.8.0 in /Users/vamshisaggurthi/opt/anaconda3/lib/python3.9/site-packages (from vaex-core<4.9,>=4.8.0->vaex) (1.9.0)
# Requirement already satisfied: rich in /Users/vamshisaggurthi/opt/anaconda3/lib/python3.9/site-packages (from vaex-core<4.9,>=4.8.0->vaex) (11.2.0)
# Requirement already satisfied: nest-asyncio>=1.3.3 in /Users/vamshisaggurthi/opt/anaconda3/lib/python3.9/site-packages (from vaex-core<4.9,>=4.8.0->vaex) (1.5.1)
# Requirement already satisfied: blake3 in /Users/vamshisaggurthi/opt/anaconda3/lib/python3.9/site-packages (from vaex-core<4.9,>=4.8.0->vaex) (0.2.1)
# Requirement already satisfied: requests in /Users/vamshisaggurthi/opt/anaconda3/lib/python3.9/site-packages (from vaex-core<4.9,>=4.8.0->vaex) (2.26.0)
# Requirement already satisfied: aplus in /Users/vamshisaggurthi/opt/anaconda3/lib/python3.9/site-packages (from vaex-core<4.9,>=4.8.0->vaex) (0.11.0)
# Requirement already satisfied: cloudpickle in /Users/vamshisaggurthi/opt/anaconda3/lib/python3.9/site-packages (from vaex-core<4.9,>=4.8.0->vaex) (2.0.0)
# Requirement already satisfied: filelock in /Users/vamshisaggurthi/opt/anaconda3/lib/python3.9/site-packages (from vaex-core<4.9,>=4.8.0->vaex) (3.3.1)
# Requirement already satisfied: frozendict!=2.2.0 in /Users/vamshisaggurthi/opt/anaconda3/lib/python3.9/site-packages (from vaex-core<4.9,>=4.8.0->vaex) (2.3.0)
# Requirement already satisfied: pyyaml in /Users/vamshisaggurthi/opt/anaconda3/lib/python3.9/site-packages (from vaex-core<4.9,>=4.8.0->vaex) (6.0)
# Requirement already satisfied: pyarrow>=3.0 in /Users/vamshisaggurthi/opt/anaconda3/lib/python3.9/site-packages (from vaex-core<4.9,>=4.8.0->vaex) (4.0.0)
# Requirement already satisfied: future>=0.15.2 in /Users/vamshisaggurthi/opt/anaconda3/lib/python3.9/site-packages (from vaex-core<4.9,>=4.8.0->vaex) (0.18.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/vamshisaggurthi/opt/anaconda3/lib/python3.9/site-packages (from pydantic>=1.8.0->vaex-core<4.9,>=4.8.0->vaex) (3.10.0.2)
# Requirement already satisfied: h5py>=2.9 in /Users/vamshisaggurthi/opt/anaconda3/lib/python3.9/site-packages (from vaex-hdf5<0.13,>=0.12.0->vaex) (3.2.1)
# Requirement already satisfied: ipyleaflet in /Users/vamshisaggurthi/opt/anaconda3/lib/python3.9/site-packages (from vaex-jupyter<0.8,>=0.7.0->vaex) (0.15.0)
# Requirement already satisfied: bqplot>=0.10.1 in /Users/vamshisaggurthi/opt/anaconda3/lib/python3.9/site-packages (from vaex-jupyter<0.8,>=0.7.0->vaex) (0.12.33)
# Requirement already satisfied: ipyvolume>=0.4 in /Users/vamshisaggurthi/opt/anaconda3/lib/python3.9/site-packages (from vaex-jupyter<0.8,>=0.7.0->vaex) (0.6.0a8)
# Requirement already satisfied: ipyvuetify<2,>=1.2.2 in /Users/vamshisaggurthi/opt/anaconda3/lib/python3.9/site-packages (from vaex-jupyter<0.8,>=0.7.0->vaex) (1.8.2)
# Requirement already satisfied: ipympl in /Users/vamshisaggurthi/opt/anaconda3/lib/python3.9/site-packages (from vaex-jupyter<0.8,>=0.7.0->vaex) (0.8.7)
# Requirement already satisfied: xarray in /Users/vamshisaggurthi/opt/anaconda3/lib/python3.9/site-packages (from vaex-jupyter<0.8,>=0.7.0->vaex) (0.21.1)
# Requirement already satisfied: ipywidgets>=7.5.0 in /Users/vamshisaggurthi/opt/anaconda3/lib/python3.9/site-packages (from bqplot>=0.10.1->vaex-jupyter<0.8,>=0.7.0->vaex) (7.6.5)
# Requirement already satisfied: traittypes>=0.0.6 in /Users/vamshisaggurthi/opt/anaconda3/lib/python3.9/site-packages (from bqplot>=0.10.1->vaex-jupyter<0.8,>=0.7.0->vaex) (0.2.1)
# Requirement already satisfied: traitlets>=4.3.0 in /Users/vamshisaggurthi/opt/anaconda3/lib/python3.9/site-packages (from bqplot>=0.10.1->vaex-jupyter<0.8,>=0.7.0->vaex) (5.1.0)
# Requirement already satisfied: Pillow in /Users/vamshisaggurthi/opt/anaconda3/lib/python3.9/site-packages (from ipyvolume>=0.4->vaex-jupyter<0.8,>=0.7.0->vaex) (8.4.0)
# Requirement already satisfied: ipywebrtc in /Users/vamshisaggurthi/opt/anaconda3/lib/python3.9/site-packages (from ipyvolume>=0.4->vaex-jupyter<0.8,>=0.7.0->vaex) (0.6.0)
# Requirement already satisfied: pythreejs>=2.0.0 in /Users/vamshisaggurthi/opt/anaconda3/lib/python3.9/site-packages (from ipyvolume>=0.4->vaex-jupyter<0.8,>=0.7.0->vaex) (2.3.0)
# Requirement already satisfied: matplotlib in /Users/vamshisaggurthi/opt/anaconda3/lib/python3.9/site-packages (from ipyvolume>=0.4->vaex-jupyter<0.8,>=0.7.0->vaex) (3.4.3)
# Requirement already satisfied: ipyvue<2,>=1.5 in /Users/vamshisaggurthi/opt/anaconda3/lib/python3.9/site-packages (from ipyvuetify<2,>=1.2.2->vaex-jupyter<0.8,>=0.7.0->vaex) (1.7.0)
# Requirement already satisfied: ipython>=4.0.0 in /Users/vamshisaggurthi/opt/anaconda3/lib/python3.9/site-packages (from ipywidgets>=7.5.0->bqplot>=0.10.1->vaex-jupyter<0.8,>=0.7.0->vaex) (7.29.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /Users/vamshisaggurthi/opt/anaconda3/lib/python3.9/site-packages (from ipywidgets>=7.5.0->bqplot>=0.10.1->vaex-jupyter<0.8,>=0.7.0->vaex) (1.0.0)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /Users/vamshisaggurthi/opt/anaconda3/lib/python3.9/site-packages (from ipywidgets>=7.5.0->bqplot>=0.10.1->vaex-jupyter<0.8,>=0.7.0->vaex) (0.2.0)
# Requirement already satisfied: nbformat>=4.2.0 in /Users/vamshisaggurthi/opt/anaconda3/lib/python3.9/site-packages (from ipywidgets>=7.5.0->bqplot>=0.10.1->vaex-jupyter<0.8,>=0.7.0->vaex) (5.1.3)
# Requirement already satisfied: ipykernel>=4.5.1 in /Users/vamshisaggurthi/opt/anaconda3/lib/python3.9/site-packages (from ipywidgets>=7.5.0->bqplot>=0.10.1->vaex-jupyter<0.8,>=0.7.0->vaex) (6.4.1)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in /Users/vamshisaggurthi/opt/anaconda3/lib/python3.9/site-packages (from ipywidgets>=7.5.0->bqplot>=0.10.1->vaex-jupyter<0.8,>=0.7.0->vaex) (3.5.1)
# Requirement already satisfied: tornado<7.0,>=4.2 in /Users/vamshisaggurthi/opt/anaconda3/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.0->bqplot>=0.10.1->vaex-jupyter<0.8,>=0.7.0->vaex) (6.1)
# Requirement already satisfied: jupyter-client<8.0 in /Users/vamshisaggurthi/opt/anaconda3/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.0->bqplot>=0.10.1->vaex-jupyter<0.8,>=0.7.0->vaex) (6.1.12)
# Requirement already satisfied: appnope in /Users/vamshisaggurthi/opt/anaconda3/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.0->bqplot>=0.10.1->vaex-jupyter<0.8,>=0.7.0->vaex) (0.1.2)
# Requirement already satisfied: matplotlib-inline<0.2.0,>=0.1.0 in /Users/vamshisaggurthi/opt/anaconda3/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.0->bqplot>=0.10.1->vaex-jupyter<0.8,>=0.7.0->vaex) (0.1.2)
# Requirement already satisfied: debugpy<2.0,>=1.0.0 in /Users/vamshisaggurthi/opt/anaconda3/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.0->bqplot>=0.10.1->vaex-jupyter<0.8,>=0.7.0->vaex) (1.4.1)
# Requirement already satisfied: pygments in /Users/vamshisaggurthi/opt/anaconda3/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets>=7.5.0->bqplot>=0.10.1->vaex-jupyter<0.8,>=0.7.0->vaex) (2.10.0)
# Requirement already satisfied: pickleshare in /Users/vamshisaggurthi/opt/anaconda3/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets>=7.5.0->bqplot>=0.10.1->vaex-jupyter<0.8,>=0.7.0->vaex) (0.7.5)
# Requirement already satisfied: jedi>=0.16 in /Users/vamshisaggurthi/opt/anaconda3/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets>=7.5.0->bqplot>=0.10.1->vaex-jupyter<0.8,>=0.7.0->vaex) (0.18.0)
# Requirement already satisfied: decorator in /Users/vamshisaggurthi/opt/anaconda3/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets>=7.5.0->bqplot>=0.10.1->vaex-jupyter<0.8,>=0.7.0->vaex) (5.1.0)
# Requirement already satisfied: backcall in /Users/vamshisaggurthi/opt/anaconda3/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets>=7.5.0->bqplot>=0.10.1->vaex-jupyter<0.8,>=0.7.0->vaex) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /Users/vamshisaggurthi/opt/anaconda3/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets>=7.5.0->bqplot>=0.10.1->vaex-jupyter<0.8,>=0.7.0->vaex) (4.8.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /Users/vamshisaggurthi/opt/anaconda3/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets>=7.5.0->bqplot>=0.10.1->vaex-jupyter<0.8,>=0.7.0->vaex) (3.0.20)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /Users/vamshisaggurthi/opt/anaconda3/lib/python3.9/site-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets>=7.5.0->bqplot>=0.10.1->vaex-jupyter<0.8,>=0.7.0->vaex) (0.8.2)
# Requirement already satisfied: pyzmq>=13 in /Users/vamshisaggurthi/opt/anaconda3/lib/python3.9/site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets>=7.5.0->bqplot>=0.10.1->vaex-jupyter<0.8,>=0.7.0->vaex) (22.2.1)
# Requirement already satisfied: jupyter-core>=4.6.0 in /Users/vamshisaggurthi/opt/anaconda3/lib/python3.9/site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets>=7.5.0->bqplot>=0.10.1->vaex-jupyter<0.8,>=0.7.0->vaex) (4.8.1)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /Users/vamshisaggurthi/opt/anaconda3/lib/python3.9/site-packages (from nbformat>=4.2.0->ipywidgets>=7.5.0->bqplot>=0.10.1->vaex-jupyter<0.8,>=0.7.0->vaex) (3.2.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in /Users/vamshisaggurthi/opt/anaconda3/lib/python3.9/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=7.5.0->bqplot>=0.10.1->vaex-jupyter<0.8,>=0.7.0->vaex) (0.18.0)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/vamshisaggurthi/opt/anaconda3/lib/python3.9/site-packages (from pexpect>4.3->ipython>=4.0.0->ipywidgets>=7.5.0->bqplot>=0.10.1->vaex-jupyter<0.8,>=0.7.0->vaex) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/vamshisaggurthi/opt/anaconda3/lib/python3.9/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets>=7.5.0->bqplot>=0.10.1->vaex-jupyter<0.8,>=0.7.0->vaex) (0.2.5)
# Requirement already satisfied: ipydatawidgets>=1.1.1 in /Users/vamshisaggurthi/opt/anaconda3/lib/python3.9/site-packages (from pythreejs>=2.0.0->ipyvolume>=0.4->vaex-jupyter<0.8,>=0.7.0->vaex) (4.2.0)
# Requirement already satisfied: numba in /Users/vamshisaggurthi/opt/anaconda3/lib/python3.9/site-packages (from vaex-ml<0.18,>=0.17.0->vaex) (0.54.1)
# Requirement already satisfied: cachetools in /Users/vamshisaggurthi/opt/anaconda3/lib/python3.9/site-packages (from vaex-server<0.9,>=0.8.1->vaex) (5.0.0)
# Requirement already satisfied: uvicorn[standard] in /Users/vamshisaggurthi/opt/anaconda3/lib/python3.9/site-packages (from vaex-server<0.9,>=0.8.1->vaex) (0.17.5)
# Requirement already satisfied: fastapi in /Users/vamshisaggurthi/opt/anaconda3/lib/python3.9/site-packages (from vaex-server<0.9,>=0.8.1->vaex) (0.65.0)
# Requirement already satisfied: cycler>=0.10 in /Users/vamshisaggurthi/opt/anaconda3/lib/python3.9/site-packages (from matplotlib->ipyvolume>=0.4->vaex-jupyter<0.8,>=0.7.0->vaex) (0.10.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/vamshisaggurthi/opt/anaconda3/lib/python3.9/site-packages (from matplotlib->ipyvolume>=0.4->vaex-jupyter<0.8,>=0.7.0->vaex) (3.0.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/vamshisaggurthi/opt/anaconda3/lib/python3.9/site-packages (from matplotlib->ipyvolume>=0.4->vaex-jupyter<0.8,>=0.7.0->vaex) (1.3.1)
# Requirement already satisfied: notebook>=4.4.1 in /Users/vamshisaggurthi/opt/anaconda3/lib/python3.9/site-packages (from widgetsnbextension~=3.5.0->ipywidgets>=7.5.0->bqplot>=0.10.1->vaex-jupyter<0.8,>=0.7.0->vaex) (6.4.5)
# Requirement already satisfied: terminado>=0.8.3 in /Users/vamshisaggurthi/opt/anaconda3/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.0->bqplot>=0.10.1->vaex-jupyter<0.8,>=0.7.0->vaex) (0.9.4)
# Requirement already satisfied: argon2-cffi in /Users/vamshisaggurthi/opt/anaconda3/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.0->bqplot>=0.10.1->vaex-jupyter<0.8,>=0.7.0->vaex) (20.1.0)
# Requirement already satisfied: nbconvert in /Users/vamshisaggurthi/opt/anaconda3/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.0->bqplot>=0.10.1->vaex-jupyter<0.8,>=0.7.0->vaex) (6.1.0)
# Requirement already satisfied: Send2Trash>=1.5.0 in /Users/vamshisaggurthi/opt/anaconda3/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.0->bqplot>=0.10.1->vaex-jupyter<0.8,>=0.7.0->vaex) (1.8.0)
# Requirement already satisfied: prometheus-client in /Users/vamshisaggurthi/opt/anaconda3/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.0->bqplot>=0.10.1->vaex-jupyter<0.8,>=0.7.0->vaex) (0.11.0)
# Requirement already satisfied: cffi>=1.0.0 in /Users/vamshisaggurthi/opt/anaconda3/lib/python3.9/site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.0->bqplot>=0.10.1->vaex-jupyter<0.8,>=0.7.0->vaex) (1.14.6)
# Requirement already satisfied: pycparser in /Users/vamshisaggurthi/opt/anaconda3/lib/python3.9/site-packages (from cffi>=1.0.0->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.0->bqplot>=0.10.1->vaex-jupyter<0.8,>=0.7.0->vaex) (2.20)
# Requirement already satisfied: pyerfa>=1.7.3 in /Users/vamshisaggurthi/opt/anaconda3/lib/python3.9/site-packages (from astropy->vaex-astro<0.10,>=0.9.0->vaex) (2.0.0)
# Requirement already satisfied: fsspec>=0.6.0 in /Users/vamshisaggurthi/opt/anaconda3/lib/python3.9/site-packages (from dask->vaex-core<4.9,>=4.8.0->vaex) (2021.8.1)
# Requirement already satisfied: packaging>=20.0 in /Users/vamshisaggurthi/opt/anaconda3/lib/python3.9/site-packages (from dask->vaex-core<4.9,>=4.8.0->vaex) (21.0)
# Requirement already satisfied: partd>=0.3.10 in /Users/vamshisaggurthi/opt/anaconda3/lib/python3.9/site-packages (from dask->vaex-core<4.9,>=4.8.0->vaex) (1.2.0)
# Requirement already satisfied: toolz>=0.8.2 in /Users/vamshisaggurthi/opt/anaconda3/lib/python3.9/site-packages (from dask->vaex-core<4.9,>=4.8.0->vaex) (0.11.1)
# Requirement already satisfied: locket in /Users/vamshisaggurthi/opt/anaconda3/lib/python3.9/site-packages/locket-0.2.1-py3.9.egg (from partd>=0.3.10->dask->vaex-core<4.9,>=4.8.0->vaex) (0.2.1)
# Requirement already satisfied: starlette==0.14.2 in /Users/vamshisaggurthi/opt/anaconda3/lib/python3.9/site-packages (from fastapi->vaex-server<0.9,>=0.8.1->vaex) (0.14.2)
# Requirement already satisfied: brotli in /Users/vamshisaggurthi/opt/anaconda3/lib/python3.9/site-packages (from flask-compress->dash) (1.0.9)
# Requirement already satisfied: xyzservices>=2021.8.1 in /Users/vamshisaggurthi/opt/anaconda3/lib/python3.9/site-packages (from ipyleaflet->vaex-jupyter<0.8,>=0.7.0->vaex) (2022.2.0)
# Requirement already satisfied: entrypoints>=0.2.2 in /Users/vamshisaggurthi/opt/anaconda3/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.0->bqplot>=0.10.1->vaex-jupyter<0.8,>=0.7.0->vaex) (0.3)
# Requirement already satisfied: defusedxml in /Users/vamshisaggurthi/opt/anaconda3/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.0->bqplot>=0.10.1->vaex-jupyter<0.8,>=0.7.0->vaex) (0.7.1)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in /Users/vamshisaggurthi/opt/anaconda3/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.0->bqplot>=0.10.1->vaex-jupyter<0.8,>=0.7.0->vaex) (0.5.3)
# Requirement already satisfied: testpath in /Users/vamshisaggurthi/opt/anaconda3/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.0->bqplot>=0.10.1->vaex-jupyter<0.8,>=0.7.0->vaex) (0.5.0)
# Requirement already satisfied: jupyterlab-pygments in /Users/vamshisaggurthi/opt/anaconda3/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.0->bqplot>=0.10.1->vaex-jupyter<0.8,>=0.7.0->vaex) (0.1.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in /Users/vamshisaggurthi/opt/anaconda3/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.0->bqplot>=0.10.1->vaex-jupyter<0.8,>=0.7.0->vaex) (1.4.3)
# Requirement already satisfied: mistune<2,>=0.8.1 in /Users/vamshisaggurthi/opt/anaconda3/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.0->bqplot>=0.10.1->vaex-jupyter<0.8,>=0.7.0->vaex) (0.8.4)
# Requirement already satisfied: bleach in /Users/vamshisaggurthi/opt/anaconda3/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.0->bqplot>=0.10.1->vaex-jupyter<0.8,>=0.7.0->vaex) (4.0.0)
# Requirement already satisfied: async-generator in /Users/vamshisaggurthi/opt/anaconda3/lib/python3.9/site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.0->bqplot>=0.10.1->vaex-jupyter<0.8,>=0.7.0->vaex) (1.10)
# Requirement already satisfied: webencodings in /Users/vamshisaggurthi/opt/anaconda3/lib/python3.9/site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.0->bqplot>=0.10.1->vaex-jupyter<0.8,>=0.7.0->vaex) (0.5.1)
# Requirement already satisfied: llvmlite<0.38,>=0.37.0rc1 in /Users/vamshisaggurthi/opt/anaconda3/lib/python3.9/site-packages (from numba->vaex-ml<0.18,>=0.17.0->vaex) (0.37.0)
# Requirement already satisfied: python-utils>=3.0.0 in /Users/vamshisaggurthi/opt/anaconda3/lib/python3.9/site-packages (from progressbar2->vaex-core<4.9,>=4.8.0->vaex) (3.1.0)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Users/vamshisaggurthi/opt/anaconda3/lib/python3.9/site-packages (from requests->vaex-core<4.9,>=4.8.0->vaex) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/vamshisaggurthi/opt/anaconda3/lib/python3.9/site-packages (from requests->vaex-core<4.9,>=4.8.0->vaex) (3.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/vamshisaggurthi/opt/anaconda3/lib/python3.9/site-packages (from requests->vaex-core<4.9,>=4.8.0->vaex) (1.26.7)
# Requirement already satisfied: colorama<0.5.0,>=0.4.0 in /Users/vamshisaggurthi/opt/anaconda3/lib/python3.9/site-packages (from rich->vaex-core<4.9,>=4.8.0->vaex) (0.4.4)
# Requirement already satisfied: commonmark<0.10.0,>=0.9.0 in /Users/vamshisaggurthi/opt/anaconda3/lib/python3.9/site-packages (from rich->vaex-core<4.9,>=4.8.0->vaex) (0.9.1)
# Requirement already satisfied: asgiref>=3.4.0 in /Users/vamshisaggurthi/opt/anaconda3/lib/python3.9/site-packages (from uvicorn[standard]->vaex-server<0.9,>=0.8.1->vaex) (3.5.0)
# Requirement already satisfied: h11>=0.8 in /Users/vamshisaggurthi/opt/anaconda3/lib/python3.9/site-packages (from uvicorn[standard]->vaex-server<0.9,>=0.8.1->vaex) (0.13.0)
# Requirement already satisfied: watchgod>=0.6 in /Users/vamshisaggurthi/opt/anaconda3/lib/python3.9/site-packages (from uvicorn[standard]->vaex-server<0.9,>=0.8.1->vaex) (0.7)
# Requirement already satisfied: websockets>=10.0 in /Users/vamshisaggurthi/opt/anaconda3/lib/python3.9/site-packages (from uvicorn[standard]->vaex-server<0.9,>=0.8.1->vaex) (10.2)
# Requirement already satisfied: uvloop!=0.15.0,!=0.15.1,>=0.14.0 in /Users/vamshisaggurthi/opt/anaconda3/lib/python3.9/site-packages (from uvicorn[standard]->vaex-server<0.9,>=0.8.1->vaex) (0.16.0)
# Requirement already satisfied: python-dotenv>=0.13 in /Users/vamshisaggurthi/opt/anaconda3/lib/python3.9/site-packages (from uvicorn[standard]->vaex-server<0.9,>=0.8.1->vaex) (0.19.2)
# Requirement already satisfied: httptools<0.4.0,>=0.2.0 in /Users/vamshisaggurthi/opt/anaconda3/lib/python3.9/site-packages (from uvicorn[standard]->vaex-server<0.9,>=0.8.1->vaex) (0.3.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install jupyter-dash
# Out:
# Requirement already satisfied: jupyter-dash in /Users/vamshisaggurthi/opt/anaconda3/lib/python3.9/site-packages (0.4.1)
# Requirement already satisfied: flask in /Users/vamshisaggurthi/opt/anaconda3/lib/python3.9/site-packages (from jupyter-dash) (1.1.2)
# Requirement already satisfied: dash in /Users/vamshisaggurthi/opt/anaconda3/lib/python3.9/site-packages (from jupyter-dash) (2.2.0)
# Requirement already satisfied: ipython in /Users/vamshisaggurthi/opt/anaconda3/lib/python3.9/site-packages (from jupyter-dash) (7.29.0)
# Requirement already satisfied: ansi2html in /Users/vamshisaggurthi/opt/anaconda3/lib/python3.9/site-packages (from jupyter-dash) (1.7.0)
# Requirement already satisfied: retrying in /Users/vamshisaggurthi/opt/anaconda3/lib/python3.9/site-packages (from jupyter-dash) (1.3.3)
# Requirement already satisfied: ipykernel in /Users/vamshisaggurthi/opt/anaconda3/lib/python3.9/site-packages (from jupyter-dash) (6.4.1)
# Requirement already satisfied: requests in /Users/vamshisaggurthi/opt/anaconda3/lib/python3.9/site-packages (from jupyter-dash) (2.26.0)
# Requirement already satisfied: dash-html-components==2.0.0 in /Users/vamshisaggurthi/opt/anaconda3/lib/python3.9/site-packages (from dash->jupyter-dash) (2.0.0)
# Requirement already satisfied: plotly>=5.0.0 in /Users/vamshisaggurthi/opt/anaconda3/lib/python3.9/site-packages (from dash->jupyter-dash) (5.6.0)
# Requirement already satisfied: dash-core-components==2.0.0 in /Users/vamshisaggurthi/opt/anaconda3/lib/python3.9/site-packages (from dash->jupyter-dash) (2.0.0)
# Requirement already satisfied: dash-table==5.0.0 in /Users/vamshisaggurthi/opt/anaconda3/lib/python3.9/site-packages (from dash->jupyter-dash) (5.0.0)
# Requirement already satisfied: flask-compress in /Users/vamshisaggurthi/opt/anaconda3/lib/python3.9/site-packages (from dash->jupyter-dash) (1.11)
# Requirement already satisfied: Jinja2>=2.10.1 in /Users/vamshisaggurthi/opt/anaconda3/lib/python3.9/site-packages (from flask->jupyter-dash) (2.11.3)
# Requirement already satisfied: Werkzeug>=0.15 in /Users/vamshisaggurthi/opt/anaconda3/lib/python3.9/site-packages (from flask->jupyter-dash) (2.0.2)
# Requirement already satisfied: itsdangerous>=0.24 in /Users/vamshisaggurthi/opt/anaconda3/lib/python3.9/site-packages (from flask->jupyter-dash) (2.0.1)
# Requirement already satisfied: click>=5.1 in /Users/vamshisaggurthi/opt/anaconda3/lib/python3.9/site-packages (from flask->jupyter-dash) (8.0.3)
# Requirement already satisfied: MarkupSafe>=0.23 in /Users/vamshisaggurthi/opt/anaconda3/lib/python3.9/site-packages (from Jinja2>=2.10.1->flask->jupyter-dash) (1.1.1)
# Requirement already satisfied: six in /Users/vamshisaggurthi/opt/anaconda3/lib/python3.9/site-packages (from plotly>=5.0.0->dash->jupyter-dash) (1.16.0)
# Requirement already satisfied: tenacity>=6.2.0 in /Users/vamshisaggurthi/opt/anaconda3/lib/python3.9/site-packages (from plotly>=5.0.0->dash->jupyter-dash) (8.0.1)
# Requirement already satisfied: brotli in /Users/vamshisaggurthi/opt/anaconda3/lib/python3.9/site-packages (from flask-compress->dash->jupyter-dash) (1.0.9)
# Requirement already satisfied: traitlets<6.0,>=4.1.0 in /Users/vamshisaggurthi/opt/anaconda3/lib/python3.9/site-packages (from ipykernel->jupyter-dash) (5.1.0)
# Requirement already satisfied: matplotlib-inline<0.2.0,>=0.1.0 in /Users/vamshisaggurthi/opt/anaconda3/lib/python3.9/site-packages (from ipykernel->jupyter-dash) (0.1.2)
# Requirement already satisfied: tornado<7.0,>=4.2 in /Users/vamshisaggurthi/opt/anaconda3/lib/python3.9/site-packages (from ipykernel->jupyter-dash) (6.1)
# Requirement already satisfied: appnope in /Users/vamshisaggurthi/opt/anaconda3/lib/python3.9/site-packages (from ipykernel->jupyter-dash) (0.1.2)
# Requirement already satisfied: debugpy<2.0,>=1.0.0 in /Users/vamshisaggurthi/opt/anaconda3/lib/python3.9/site-packages (from ipykernel->jupyter-dash) (1.4.1)
# Requirement already satisfied: ipython-genutils in /Users/vamshisaggurthi/opt/anaconda3/lib/python3.9/site-packages (from ipykernel->jupyter-dash) (0.2.0)
# Requirement already satisfied: jupyter-client<8.0 in /Users/vamshisaggurthi/opt/anaconda3/lib/python3.9/site-packages (from ipykernel->jupyter-dash) (6.1.12)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /Users/vamshisaggurthi/opt/anaconda3/lib/python3.9/site-packages (from ipython->jupyter-dash) (3.0.20)
# Requirement already satisfied: pickleshare in /Users/vamshisaggurthi/opt/anaconda3/lib/python3.9/site-packages (from ipython->jupyter-dash) (0.7.5)
# Requirement already satisfied: pygments in /Users/vamshisaggurthi/opt/anaconda3/lib/python3.9/site-packages (from ipython->jupyter-dash) (2.10.0)
# Requirement already satisfied: decorator in /Users/vamshisaggurthi/opt/anaconda3/lib/python3.9/site-packages (from ipython->jupyter-dash) (5.1.0)
# Requirement already satisfied: backcall in /Users/vamshisaggurthi/opt/anaconda3/lib/python3.9/site-packages (from ipython->jupyter-dash) (0.2.0)
# Requirement already satisfied: setuptools>=18.5 in /Users/vamshisaggurthi/opt/anaconda3/lib/python3.9/site-packages (from ipython->jupyter-dash) (58.0.4)
# Requirement already satisfied: jedi>=0.16 in /Users/vamshisaggurthi/opt/anaconda3/lib/python3.9/site-packages (from ipython->jupyter-dash) (0.18.0)
# Requirement already satisfied: pexpect>4.3 in /Users/vamshisaggurthi/opt/anaconda3/lib/python3.9/site-packages (from ipython->jupyter-dash) (4.8.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /Users/vamshisaggurthi/opt/anaconda3/lib/python3.9/site-packages (from jedi>=0.16->ipython->jupyter-dash) (0.8.2)
# Requirement already satisfied: pyzmq>=13 in /Users/vamshisaggurthi/opt/anaconda3/lib/python3.9/site-packages (from jupyter-client<8.0->ipykernel->jupyter-dash) (22.2.1)
# Requirement already satisfied: python-dateutil>=2.1 in /Users/vamshisaggurthi/opt/anaconda3/lib/python3.9/site-packages (from jupyter-client<8.0->ipykernel->jupyter-dash) (2.8.2)
# Requirement already satisfied: jupyter-core>=4.6.0 in /Users/vamshisaggurthi/opt/anaconda3/lib/python3.9/site-packages (from jupyter-client<8.0->ipykernel->jupyter-dash) (4.8.1)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/vamshisaggurthi/opt/anaconda3/lib/python3.9/site-packages (from pexpect>4.3->ipython->jupyter-dash) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/vamshisaggurthi/opt/anaconda3/lib/python3.9/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->jupyter-dash) (0.2.5)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/vamshisaggurthi/opt/anaconda3/lib/python3.9/site-packages (from requests->jupyter-dash) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Users/vamshisaggurthi/opt/anaconda3/lib/python3.9/site-packages (from requests->jupyter-dash) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/vamshisaggurthi/opt/anaconda3/lib/python3.9/site-packages (from requests->jupyter-dash) (3.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/vamshisaggurthi/opt/anaconda3/lib/python3.9/site-packages (from requests->jupyter-dash) (1.26.7)
# Note: you may need to restart the kernel to use updated packages.

# %%
import json
import logging
import os

from jupyter_dash import JupyterDash
from dash import Dash, html, dcc
import plotly.express as px
import pandas as pd
import plotly.figure_factory as ff

# %%
# JupyterDash.infer_jupyter_proxy_config()

# %%
df = pd.read_csv('https://plotly.github.io/datasets/country_indicators.csv')
available_indicators = df['Indicator Name'].unique()

# %%
# app intialisation 
app = JupyterDash(__name__)

# %%
# # cache setup 
# cache = Cache(app.server, config={
#     'CACHE_TYPE': 'filesystem',
#     'CACHE_DIR': 'cache-directory'
# })

# # time out 
# CACHE_TIMEOUT = int(os.environ.get('DASH_CACHE_TIMEOUT', '60'))

# %%
df = pd.DataFrame({
    "Fruit": ["Apples", "Oranges", "Bananas", "Apples", "Oranges", "Bananas"],
    "Amount": [4, 1, 2, 2, 4, 5],
    "City": ["SF", "SF", "SF", "Montreal", "Montreal", "Montreal"]
})

fig = px.bar(df, x="Fruit", y="Amount", color="City", barmode="group")


def create_geomap():
    scope = ['Oregon']
    df_sample = pd.read_csv(
        'https://raw.githubusercontent.com/plotly/datasets/master/minoritymajority.csv')
    df_sample_r = df_sample[df_sample['STNAME'].isin(scope)]

    values = df_sample_r['TOT_POP'].tolist()
    fips = df_sample_r['FIPS'].tolist()

    colorscale = ["#8dd3c7", "#ffffb3", "#bebada", "#fb8072",
                  "#80b1d3", "#fdb462", "#b3de69", "#fccde5",
                  "#d9d9d9", "#bc80bd", "#ccebc5", "#ffed6f",
                  "#8dd3c7", "#ffffb3", "#bebada", "#fb8072",
                  "#80b1d3", "#fdb462", "#b3de69", "#fccde5",
                  "#d9d9d9", "#bc80bd", "#ccebc5", "#ffed6f",
                  "#8dd3c7", "#ffffb3", "#bebada", "#fb8072",
                  "#80b1d3", "#fdb462", "#b3de69", "#fccde5",
                  "#d9d9d9", "#bc80bd", "#ccebc5", "#ffed6f"]

    fig = ff.create_choropleth(
        fips=fips,
        values=values,
        scope=scope,
        colorscale=colorscale,
        round_legend_values=True,
        simplify_county=0,
        simplify_state=0,
        county_outline={'color': 'rgb(15, 15, 55)', 'width': 0.5},
        state_outline={'width': 1},
        legend_title='pop. per county',
        title='Illinois')

    fig.layout.template = None
    return fig


app.layout = html.Div([
    html.Div(children=[
        html.Br(),
        html.Label('District Dropdown'),
        dcc.Dropdown(['1', '2', '3', '4', '5','10','12'],
                     ['1', '3'],
                     multi=True),
    ], style={'padding': 10, 'flex': 1}),

    # auto compute theft types

    # html.Div(children=[
    #     html.Br(),
    #     html.Label('District Dropdown'),
    #     dcc.Dropdown(df_vaex.unique('Primary Type'),
    #                  ['Theft'],
    #                  multi=True),
    # ], style={'padding': 10, 'flex': 1})

    html.Div(children=[
        html.Br(),
        html.Label('Slider'),
        dcc.RangeSlider(
            2001,
            2022,
            1,
            marks={i: f'{i}' for i in range(2001, 2022, 5)},
            value=[2001, 2010],
            tooltip={"placement": "bottom", "always_visible": True}
        ),

        # autumatic year slider

        # dcc.RangeSlider(
        #     df['year'].min(),
        #     df['year'].max(),
        #     step=None,
        #     value=df['year'].min(),
        #     marks={str(year): str(year) for year in df['year'].unique()},
        #     id='year-slider'
        # )

    ], style={'padding': 10, 'flex': 1}),

    # html.Div(children=[
    #     dcc.Graph(id='geomap_figure',
    #               figure=create_geomap(),
    #               )
    # ])


], style={'display': 'flex', 'flex-direction': 'column'})

# %%
app.run_server(mode='inline')
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8050/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
